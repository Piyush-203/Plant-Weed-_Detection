# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8s.pt')

# %%
# !touch data.yaml
# Out:
# 'touch' is not recognized as an internal or external command,
# operable program or batch file.

# %%
model.train(data='C:/Users/Dell/OneDrive/Desktop/Projects/Apple_detection_using_YOLO/yolo_Model+code/data.yaml', epochs=5,
    imgsz=416,
    lr0=1e-3,
    lrf=0.01,
    batch=8
 )
# Out:
# Ultralytics YOLOv8.2.81  Python-3.11.2 torch-2.0.0+cpu CPU (11th Gen Intel Core(TM) i5-11320H 3.20GHz)
# ...

# %%
infer = YOLO('C:/Users/Dell/runs/detect/train4/weights/best.pt')

# %%
infer.predict("C:/Users/Dell/OneDrive/Desktop/Projects/Apple_detection_using_YOLO/yolo_Model+code/Weeds.v3-augmented_nottrained.yolov8/test/images", save = True, save_txt = True)
# Out:
# image 1/180 C:\Users\Dell\OneDrive\Desktop\Projects\Apple_detection_using_YOLO\yolo_Model+code\Weeds.v3-augmented_nottrained.yolov8\test\images\20210907_153931_x264_mp4-1001_jpg.rf.10e747b443d1cd1f28967b51504cc446.jpg: 640x640 (no detections), 326.6ms
# image 2/180 C:\Users\Dell\OneDrive\Desktop\Projects\Apple_detection_using_YOLO\yolo_Model+code\Weeds.v3-augmented_nottrained.yolov8\test\images\20210907_153931_x264_mp4-1007_jpg.rf.c11266cd6af9ec693efd1e98ae6005c2.jpg: 640x640 (no detections), 351.1ms
# image 3/180 C:\Users\Dell\OneDrive\Desktop\Projects\Apple_detection_using_YOLO\yolo_Model+code\Weeds.v3-augmented_nottrained.yolov8\test\images\20210907_153931_x264_mp4-1011_jpg.rf.fba5ba71a2e096e352d4feb2944fe727.jpg: 640x640 (no detections), 243.5ms
# ...
